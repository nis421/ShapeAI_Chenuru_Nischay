# %% [markdown]
# {
#
# "nbformat": 4,
#
# "nbformat_minor": 0,
#
# "metadata": {
#
# "colab": {
#
# "name": "Chenuru Nischay.ipynb",
#
# "provenance": \[\]
#
# },
#
# "kernelspec": {
#
# "name": "python3",
#
# "display_name": "Python 3"
#
# },
#
# "language_info": {
#
# "name": "python"
#
# }
#
# },
#
# "cells": \[
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "woVMCKR0PSnN"
#
# },
#
# "source": \[
#
# "from keras.datasets import mnist\\n",
#
# "data=mnist.load_data()"
#
# \],
#
# "execution_count": 13,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base_uri": "https://localhost:8080/"
#
# },
#
# "id": "ZDrZ4ZQbQDEe",
#
# "outputId": "fa2b3ef1-5dcd-4ebd-cbcc-c9140423b047"
#
# },
#
# "source": \[
#
# "data\\n",
#
# "type(data)"
#
# \],
#
# "execution_count": 3,
#
# "outputs": \[
#
# {
#
# "output_type": "execute_result",
#
# "data": {
#
# "text/plain": \[
#
# "tuple"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution_count": 3
#
# }
#
# \]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "vIWsl-h_Qb1W"
#
# },
#
# "source": \[
#
# "((x_train,y_train),(x_test,y_test))=data"
#
# \],
#
# "execution_count": 15,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base_uri": "https://localhost:8080/"
#
# },
#
# "id": "yYe8YcSVSju2",
#
# "outputId": "eb4c4386-c76e-4606-90a7-c88391a845e4"
#
# },
#
# "source": \[
#
# "x_train\[0\].shape"
#
# \],
#
# "execution_count": 16,
#
# "outputs": \[
#
# {
#
# "output_type": "execute_result",
#
# "data": {
#
# "text/plain": \[
#
# "(28, 28)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution_count": 16
#
# }
#
# \]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "Ji96akXgUKbr"
#
# },
#
# "source": \[
#
# "\# reshape the training data\\n",
#
# "x_train=x_train.reshape((x_train.shape\[0\],28\*28)).astype('float32')\\n",
#
# "x_test=x_test.reshape((x_test.shape\[0\],28\*28)).astype('float32')"
#
# \],
#
# "execution_count": 17,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "WWAydNxa3dAz"
#
# },
#
# "source": \[
#
# "\#Normalising the data from 0-255 to 0-1\\n",
#
# "x_train=x_train/255\\n",
#
# "x_test=x_test/255"
#
# \],
#
# "execution_count": 18,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "ldGdIc8N7Jyw"
#
# },
#
# "source": \[
#
# "from keras.utils import np_utils\\n",
#
# "y_train=np_utils.to_categorical(y_train)\\n",
#
# "y_test=np_utils.to_categorical(y_test)\\n",
#
# "num_classes=y_test.shape\[1\]"
#
# \],
#
# "execution_count": 20,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "dz8AxqbW-Uby"
#
# },
#
# "source": \[
#
# "from keras.models import Sequential\\n",
#
# "from keras.layers import Dense\\n",
#
# "from keras.layers import Dropout"
#
# \],
#
# "execution_count": 23,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "RH4oK8UW_Cht"
#
# },
#
# "source": \[
#
# "\#define model\\n",
#
# "model=Sequential()\\n",
#
# "\#Add first Hidden layer\\n",
#
# "model.add(Dense(32,input_dim=28\*28,activation='relu'))\\n",
#
# "\#Add Second Hidden Layer\\n",
#
# "model.add(Dense(64,activation='relu'))\\n",
#
# "\#Add output layer having 10 Neurons\\n",
#
# "model.add(Dense(10,activation='softmax'))"
#
# \],
#
# "execution_count": 25,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "gOVQv1-4ANmX"
#
# },
#
# "source": \[
#
# "\#model compile\\n",
#
# "model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=\['accuracy'\])\\n"
#
# \],
#
# "execution_count": 27,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base_uri": "https://localhost:8080/"
#
# },
#
# "id": "PwlyBAltBC2M",
#
# "outputId": "7c232a0b-6356-4fe3-8539-c20c957a393d"
#
# },
#
# "source": \[
#
# "\#print model summary\\n",
#
# "model.summary()"
#
# \],
#
# "execution_count": 28,
#
# "outputs": \[
#
# {
#
# "output_type": "stream",
#
# "text": \[
#
# "Model: \\"sequential\\"\\n",
#
# "\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\\n",
#
# "Layer (type) Output Shape Param \# \\n",
#
# "=================================================================\\n",
#
# "dense (Dense) (None, 32) 25120 \\n",
#
# "\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\\n",
#
# "dense_1 (Dense) (None, 64) 2112 \\n",
#
# "\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\\n",
#
# "dense_2 (Dense) (None, 10) 650 \\n",
#
# "=================================================================\\n",
#
# "Total params: 27,882\\n",
#
# "Trainable params: 27,882\\n",
#
# "Non-trainable params: 0\\n",
#
# "\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base_uri": "https://localhost:8080/"
#
# },
#
# "id": "7Out_k4OBaNw",
#
# "outputId": "c1a3f75c-47d9-4587-e7b0-b1ddd5231dd3"
#
# },
#
# "source": \[
#
# "\#Train the model\\n",
#
# "model.fit(x_train,y_train,epochs=10,batch_size=100 )"
#
# \],
#
# "execution_count": 30,
#
# "outputs": \[
#
# {
#
# "output_type": "stream",
#
# "text": \[
#
# "Epoch 1/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0819
# - accuracy: 0.9752\\n",
#
# "Epoch 2/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0733
# - accuracy: 0.9779\\n",
#
# "Epoch 3/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0672
# - accuracy: 0.9793\\n",
#
# "Epoch 4/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0628
# - accuracy: 0.9807\\n",
#
# "Epoch 5/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0589
# - accuracy: 0.9815\\n",
#
# "Epoch 6/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0535
# - accuracy: 0.9830\\n",
#
# "Epoch 7/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0498
# - accuracy: 0.9843\\n",
#
# "Epoch 8/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0456
# - accuracy: 0.9857\\n",
#
# "Epoch 9/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0439
# - accuracy: 0.9861\\n",
#
# "Epoch 10/10\\n",
#
# "600/600 \[==============================\] - 1s 2ms/step - loss: 0.0399
# - accuracy: 0.9874\\n"
#
# \],
#
# "name": "stdout"
#
# },
#
# {
#
# "output_type": "execute_result",
#
# "data": {
#
# "text/plain": \[
#
# "\<tensorflow.python.keras.callbacks.History at 0x7fe5ae233b90\>"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution_count": 30
#
# }
#
# \]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base_uri": "https://localhost:8080/"
#
# },
#
# "id": "6QJAgit4CSvJ",
#
# "outputId": "8c8e3c0f-22e2-4c23-e9af-5f5934088ed9"
#
# },
#
# "source": \[
#
# "scores=model.evaluate(x_test,y_test)\\n",
#
# "print(scores)"
#
# \],
#
# "execution_count": 31,
#
# "outputs": \[
#
# {
#
# "output_type": "stream",
#
# "text": \[
#
# "313/313 \[==============================\] - 1s 1ms/step - loss: 0.1006
# - accuracy: 0.9714\\n",
#
# "\[0.10060695558786392, 0.9714000225067139\]\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell_type": "code",
#
# "metadata": {
#
# "id": "449mgvR2CnkP"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution_count": null,
#
# "outputs": \[\]
#
# }
#
# \]
#
# }
